# %%
import pyodbc

# Define connection string
conn_str = (
    "DRIVER={SnowflakeDSIIDriver};"
    "SERVER=.snowflakecomputing.com;"
    "DATABASE=;"
    "UID=;"
    "AUTHENTICATOR=programmatic_access_token;"
    "PWD=;"
    "TOKEN=eyJraWQiOiI2ODE2NDEzNzY2NTc0MTgiLCJhbGciOiJFUzI1NiJ9.eyJwIjoiMTA0MDEwMjI5MTc6MTA0MDEwMjMxMTMiLCJpc3MiOiJTRjoxMDQzIiwiZXhwIjoxNzU1OTY0MTc1fQ.HwWep4i8c8E6_K_9f2jhFEhddKilGC9-U2EBWHXUi5QHaAYa73hp2W6tbZeOUjILS_3jB-fDMXsYyyRUXd9jEg;"
)

# Connect to Snowflake
conn = pyodbc.connect(conn_str)
cursor = conn.cursor()

# Run a query
'''cursor.execute("SELECT * FROM YOUR_TABLE LIMIT 10")
rows = cursor.fetchall()

# Display results
for row in rows:
    print(row)
'''

# %%
import pyodbc

# Define connection string
conn_str = (
    "DRIVER={SnowflakeDSIIDriver};"
    "SERVER=.snowflakecomputing.com;"
    "DATABASE=JBS_DATASETS;"
    "UID=;"
    "AUTHENTICATOR=externalbrowser;")

# Connect to Snowflake
conn = pyodbc.connect(conn_str)
cursor = conn.cursor()

# %%
cursor.execute("Select * from JBS_DATASETS.FIPS.FIPS")
rows = cursor.fetchall()

# Display results
for row in rows:
    print(row)
# Out:
# ('Alabama', Decimal('1'), 'Autauga County, AL', Decimal('1001'), Decimal('55869'))
# ('Alabama', Decimal('1'), 'Baldwin County, AL', Decimal('1003'), Decimal('223234'))
# ('Alabama', Decimal('1'), 'Barbour County, AL', Decimal('1005'), Decimal('24686'))
# ('Alabama', Decimal('1'), 'Bibb County, AL', Decimal('1007'), Decimal('22394'))
# ('Alabama', Decimal('1'), 'Blount County, AL', Decimal('1009'), Decimal('57826'))
# ('Alabama', Decimal('1'), 'Bullock County, AL', Decimal('1011'), Decimal('10101'))
# ('Alabama', Decimal('1'), 'Butler County, AL', Decimal('1013'), Decimal('19448'))
# ('Alabama', Decimal('1'), 'Calhoun County, AL', Decimal('1015'), Decimal('113605'))
# ('Alabama', Decimal('1'), 'Chambers County, AL', Decimal('1017'), Decimal('33254'))
# ('Alabama', Decimal('1'), 'Cherokee County, AL', Decimal('1019'), Decimal('26196'))
# ('Alabama', Decimal('1'), 'Chilton County, AL', Decimal('1021'), Decimal('44428'))
# ...
