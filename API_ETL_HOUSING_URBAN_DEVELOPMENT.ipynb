# %%
import pandas as pd
import requests


# Set File Paths https://www.huduser.gov/portal/dataset/uspszip-api.html
api_token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9..eGjaWb2S6iWqwSzwJwzBLFDwNS-eYefI2LcOZBhWHZE_Tg4a_goTI6sveRweEAPiCi3BCIGR__QrnF8qsZbN1g"  # API Token (DO NOT SHARE PUBLICLY)
api_url = "https://www.huduser.gov/hudapi/public/usps?type=7&query=All"

def get_HUD_data(token, url):

    headers = {"Authorization": "Bearer {0}".format(token)}


    response = requests.get(url, headers = headers)

    if response.status_code != 200:
        print ("Failure, see status code: {0}".format(response.status_code))
    else: 
        df = pd.DataFrame(response.json()["data"]["results"])	
        print(df)
    return df, response

# Download Survey Data
df, response = get_HUD_data(token=api_token, url=api_url)

# Read CSV into DataFrame
#df = pd.read_csv(csv_file_path)
# df = pd.read_csv(csv_file_path, encoding="utf-8-sig")
# print("CSV Loaded. First few rows:\n", df.head())
# print("Column Data Types:\n", df.dtypes)
# Out:
#       county  geoid  res_ratio  bus_ratio  oth_ratio     tot_ratio  \
# 0      02100  99827        1.0   1.000000   1.000000  1.000000e+00
# 1      02195  99833        1.0   0.000000   1.000000  1.000000e+00
# 2      02220  99835        1.0   1.000000   1.000000  1.000000e+00
# 3      02230  99840        1.0   1.000000   1.000000  1.000000e+00
# 4      02282  99689        1.0   0.000000   1.000000  1.000000e+00
# ...      ...    ...        ...        ...        ...           ...
# 54569  06037  91804        0.0   0.000000   0.000004  2.126662e-07
# 54570  06037  91182        0.0   0.000002   0.000000  2.126662e-07
# 54571  06037  90844        0.0   0.000002   0.000000  2.126662e-07
# 54572  06037  91716        0.0   0.000000   0.000004  2.126662e-07
# 54573  06037  90099        0.0   0.000000   0.000004  2.126662e-07
#
#                    city state
# 0                HAINES    AK
# 1            PETERSBURG    AK
# 2                 SITKA    AK
# 3               SKAGWAY    AK
# ...

# %%
print(df.columns)

response_json = response.json()
print(type(response_json))         # What is the top-level type?
print(response_json.keys())        # What top-level keys exist?
# Out:
# Index(['county', 'geoid', 'res_ratio', 'bus_ratio', 'oth_ratio', 'tot_ratio',
#        'city', 'state'],
#       dtype='object')
# <class 'dict'>
# dict_keys(['data'])

# %%
rows = []

# Ensure data is a list
data_list = response_json["data"]
if isinstance(data_list, dict):
    data_list = [data_list]  # wrap single dict into a list

for record in data_list:
    zip_code = record.get("input")  # safely get input
    results = record.get("results", [])
    for r in results:
        r["zip"] = zip_code
        rows.append(r)

# Convert to DataFrame
df = pd.DataFrame(rows)
print(df[['zip','geoid','tot_ratio','county','city','state']].head())
# Out:
#    zip  geoid  tot_ratio county        city state
# 0  All  99827        1.0  02100      HAINES    AK
# 1  All  99833        1.0  02195  PETERSBURG    AK
# 2  All  99835        1.0  02220       SITKA    AK
# 3  All  99840        1.0  02230     SKAGWAY    AK
# 4  All  99689        1.0  02282     YAKUTAT    AK
